# %%
import collections

# %%
dtext = open("Dracula.txt","r") #This open the Dracula.txt file and gives it the attribute "r", which means readable. The file is readable
lines = dtext.read().lower().split(' ') #This creates a list called "lines" where each item in the list is a line from the text. The '\n' is used as the separator
# lines
words = []
cnt = collections.Counter()
for section in lines:
    for c in section:
        cnt[c]+=1
cnt
# Out:
# Counter({'\n': 15973,
#          '!': 752,
#          '"': 2955,
#          '#': 1,
#          '$': 2,
#          '%': 1,
#          '&': 21,
#          "'": 1645,
#          '(': 53,
#          ')': 53,
#          '*': 683,
#          ',': 11396,
#          '-': 3923,
#          '.': 8505,
#          '/': 31,
#          '0': 64,
#          '1': 182,
#          '2': 117,
#          '3': 80,
#          '4': 57,
#          '5': 58,
#          '6': 40,
#          '7': 43,
#          '8': 45,
#          '9': 43,
#          ':': 659,
#          ';': 1684,
#          '=': 9,
#          '>': 9,
#          '?': 492,
#          '@': 2,
#          '[': 3,
#          ']': 3,
#          '_': 995,
#          'a': 53800,
#          'b': 9332,
#          'c': 14235,
#          'd': 29268,
#          'e': 81719,
#          'f': 14478,
#          'g': 13194,
#          'h': 44084,
#          'i': 44122,
#          'j': 925,
#          'k': 6380,
#          'l': 26851,
#          'm': 18257,
#          'n': 44942,
#          'o': 52023,
#          'p': 9733,
#          'q': 640,
#          'r': 36525,
#          's': 40612,
#          't': 60136,
#          'u': 18642,
#          'v': 6066,
#          'w': 18465,
#          'x': 872,
#          'y': 13150,
#          'z': 285,
#          '{': 12,
#          '}': 12,
#          '£': 3,
#          'à': 1,
#          'á': 1,
#          'â': 2,
#          'æ': 9,
#          'è': 10,
#          'é': 3,
#          'ë': 3,
#          'ï': 2,
#          'ô': 1,
#          'ö': 9,
#          '\ufeff': 1})

# %%
type(cnt)
# Out:
# collections.Counter
